# %%
# Fix imports when running from notebooks/ folder
import sys
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Added to path: /Users/elshaday/DEV/10Academy/customer-experience-analytics-week2

# %%
from src.data import DataManager
from tabulate import tabulate
from src.analysis import KeywordExtractor, ThemeClusterer
from tabulate import tabulate
import pandas as pd
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/elshaday/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
dm = DataManager()
reviews_df = dm.load_data()

# %%
print("Showing 5 records as an overview:")
print(tabulate(reviews_df.head(), headers="keys", tablefmt="psql"))
# Out:
# Showing 5 records as an overview:
# +----+--------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+---------------+------------------+------------------+
# |    | review_id                            | review                                                                                                                                                                                                                                                                                                                                                                                                              |   rating | date                | bank   | source      | clean_review                                                                                                                                                                                                                                   |   vader_score | vader_label   |   textblob_score | textblob_label   |
# |----+--------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+---------------+------------------+------------------|
# |  0 | 0d6ae179-04ce-4b0c-900b-409198970d7a | ok                                                                                                                                                                                                                                                                                                                                                                                                                  |        1 | 2024-06-24 00:00:00 | boa    | google_play | ok                                                                                                                                                                                                                                             |        0.296  | positive      |           0.5    | positive         |
# |  1 | 2b2ff6dc-5482-4582-98ba-2ed17547e409 | Open Open service                                                                                                                                                                                                                                                                                                                                                                                                   |        5 | 2024-06-26 00:00:00 | boa    | google_play | open open service                                                                                                                                                                                                                              |        0      | neutral       |           0      | neutral          |
# |  2 | f0fe277f-65c1-461c-afad-8cd40c6ab368 | It's been two months now, I cannot do any transaction using this app. It's really disappointing. I am using bank of Abyssinia currently because it's the nearest bank to my work place. The bank is turning to the worst bank in the country day by day. They always respond to customers that they are updating their system all year long, I think that's what they train their customer service operators to do. |        1 | 2024-06-26 00:00:00 | boa    | google_play | two month cannot transaction using really disappointing using bank abyssinia currently nearest bank work place bank turning worst bank country day day always respond customer updating system year long think train customer service operator |       -0.8221 | negative      |          -0.4125 | negative         |
# |  3 | 829d9bb9-e4bc-4e04-90c2-867460eab574 | It demands to disable developer option.                                                                                                                                                                                                                                                                                                                                                                             |        1 | 2024-06-27 00:00:00 | boa    | google_play | demand disable developer option                                                                                                                                                                                                                |       -0.128  | negative      |           0      | neutral          |
# |  4 | d7273bdf-94a5-4b02-89ec-4a863195ea29 | the underrated app I've ever seen and ur banking system is Soo Idiocracy                                                                                                                                                                                                                                                                                                                                            |        1 | 2024-06-27 00:00:00 | boa    | google_play | underrated ever seen ur banking system soo idiocracy                                                                                                                                                                                           |        0      | neutral       |           0      | neutral          |
# +----+--------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+---------------+------------------+------------------+

# %%
# 1. Extract Keywords
# TfidfVectorizer with bigrams (n=1–2)
# spaCy to extract nouns/verbs if you want cleaner thematic clusters

# 2. Group keywords into themes
# 3-5 theme per bank
# Look at top TF-IDF keywords, Cluster similar keywords, Assign each cluster a theme label

# 3. Assign Theme to Each Review
# Check if any keyword from a theme appears
# Add a theme column

# 4. Group by bank and theme
# Count of each theme per bank
# Average sentiment per theme
# Top keywords per theme
# Correlation between rating and sentiment

# %%
extractor = KeywordExtractor()
clusterer = ThemeClusterer(n_clusters=5)


def analyze( df: pd.DataFrame, review_col: str, bank_col: str):
    bank_themes = {}
    for bank in df[bank_col].unique():
        bank_reviews = df.loc[df[bank_col] == bank, review_col].astype(str)
        # Extract keywords
        kw_with_scores = extractor.extract_keywords_tfidf(bank_reviews)
        keywords = [kw for kw, _ in kw_with_scores]
        # Cluster keywords into themes
        clusters = clusterer.cluster(keywords)
        themes = clusterer.assign_labels(clusters)
        bank_themes[bank] = themes

    return bank_themes


# Run per-bank theme analysis
bank_themes = analyze(
    reviews_df, review_col="clean_review", bank_col="bank"
)
# Display
for bank, themes in bank_themes.items():
    print(f"\n=== {bank} ===")
    rows = [[theme, ", ".join(words)] for theme, words in themes.items()]
    print(tabulate(rows, headers=["Theme", "Keywords"], tablefmt="grid"))
# Out:
# +--------------------------+------------+
# | Keyword                  |      Score |
# +==========================+============+
# | developer option         | 0.0169067  |
# +--------------------------+------------+
# | take long                | 0.00616281 |
# +--------------------------+------------+
# | please fix               | 0.00578658 |
# +--------------------------+------------+
# | best best                | 0.0052356  |
# +--------------------------+------------+
# | please try               | 0.0052356  |
# +--------------------------+------------+
# | turn developer           | 0.00494072 |
# +--------------------------+------------+
# | working day              | 0.00472444 |
# +--------------------------+------------+
# | user friendly            | 0.00472444 |
# +--------------------------+------------+
# | good job                 | 0.00469506 |
# +--------------------------+------------+
# | user experience          | 0.00456063 |
# +--------------------------+------------+
# | sometimes work           | 0.00452359 |
# +--------------------------+------------+
# | developer mode           | 0.00427865 |
# +--------------------------+------------+
# | phone number             | 0.00426187 |
# +--------------------------+------------+
# | fix problem              | 0.00425831 |
# +--------------------------+------------+
# | disable developer        | 0.00419098 |
# +--------------------------+------------+
# | take much                | 0.00400055 |
# +--------------------------+------------+
# | never work               | 0.00392583 |
# +--------------------------+------------+
# | working please           | 0.00386071 |
# +--------------------------+------------+
# | transfer money           | 0.0037264  |
# +--------------------------+------------+
# | good service             | 0.0034904  |
# +--------------------------+------------+
# | great service            | 0.0034904  |
# +--------------------------+------------+
# | security question        | 0.0034904  |
# +--------------------------+------------+
# | previous version         | 0.0034904  |
# +--------------------------+------------+
# | send money               | 0.0034904  |
# +--------------------------+------------+
# | work well                | 0.0034904  |
# +--------------------------+------------+
# | financial company        | 0.0034904  |
# +--------------------------+------------+
# | working properly         | 0.0034904  |
# +--------------------------+------------+
# | transferring money       | 0.0034904  |
# +--------------------------+------------+
# | work device              | 0.0034904  |
# +--------------------------+------------+
# | customer service         | 0.0034904  |
# +--------------------------+------------+
# | turn developer option    | 0.00334222 |
# +--------------------------+------------+
# | disable developer option | 0.00332062 |
# +--------------------------+------------+
# | please check             | 0.00321945 |
# +--------------------------+------------+
# | usually crash            | 0.00316585 |
# +--------------------------+------------+
# | transaction please       | 0.0030494  |
# +--------------------------+------------+
# | frequently experience    | 0.00303062 |
# +--------------------------+------------+
# | every try                | 0.00300794 |
# +--------------------------+------------+
# | worst never              | 0.00300794 |
# +--------------------------+------------+
# | work version             | 0.00297924 |
# +--------------------------+------------+
# | painfully slow           | 0.00297924 |
# +--------------------------+------------+
# | overall good             | 0.00297924 |
# +--------------------------+------------+
# | since last               | 0.00297924 |
# +--------------------------+------------+
# | know wrong               | 0.00297924 |
# +--------------------------+------------+
# | service please           | 0.00297924 |
# +--------------------------+------------+
# | fix issue                | 0.00282781 |
# +--------------------------+------------+
# | worst experience         | 0.00281575 |
# +--------------------------+------------+
# | take forever             | 0.00276823 |
# +--------------------------+------------+
# | android phone            | 0.00276823 |
# +--------------------------+------------+
# | work please              | 0.00275279 |
# +--------------------------+------------+
# | solve problem            | 0.00275279 |
# +--------------------------+------------+
# | money get                | 0.00275279 |
# +--------------------------+------------+
# | please working           | 0.00275279 |
# +--------------------------+------------+
# | type otp                 | 0.00267684 |
# +--------------------------+------------+
# | otp code                 | 0.00267684 |
# +--------------------------+------------+
# | please invest            | 0.00267684 |
# +--------------------------+------------+
# | show error               | 0.00255387 |
# +--------------------------+------------+
# | access account           | 0.00255387 |
# +--------------------------+------------+
# | crush frequently         | 0.00255014 |
# +--------------------------+------------+
# | nice easy                | 0.00254617 |
# +--------------------------+------------+
# | android version          | 0.00253279 |
# +--------------------------+------------+
# +---------------------------+------------+
# | Keyword                   |      Score |
# +===========================+============+
# | user friendly             | 0.0172164  |
# +---------------------------+------------+
# | game changer              | 0.0105385  |
# +---------------------------+------------+
# | step ahead                | 0.0103858  |
# +---------------------------+------------+
# | easy fast                 | 0.00713371 |
# +---------------------------+------------+
# | bill payment              | 0.00708787 |
# +---------------------------+------------+
# | always step               | 0.006216   |
# +---------------------------+------------+
# | user interface            | 0.00601494 |
# +---------------------------+------------+
# | best best                 | 0.00597652 |
# +---------------------------+------------+
# | stop working              | 0.00587174 |
# +---------------------------+------------+
# | developer option          | 0.00553463 |
# +---------------------------+------------+
# | always step ahead         | 0.00523943 |
# +---------------------------+------------+
# | qr code                   | 0.00504105 |
# +---------------------------+------------+
# | everything need           | 0.00471943 |
# +---------------------------+------------+
# | highly recommended        | 0.00468605 |
# +---------------------------+------------+
# | ui ux                     | 0.00462253 |
# +---------------------------+------------+
# | good job                  | 0.00426546 |
# +---------------------------+------------+
# | fast reliable             | 0.00420741 |
# +---------------------------+------------+
# | working well              | 0.00416112 |
# +---------------------------+------------+
# | good work                 | 0.00407134 |
# +---------------------------+------------+
# | fast transaction          | 0.00393598 |
# +---------------------------+------------+
# | fast secure               | 0.00391901 |
# +---------------------------+------------+
# | fast easy                 | 0.00387028 |
# +---------------------------+------------+
# | please try                | 0.00350821 |
# +---------------------------+------------+
# | thing need                | 0.00343643 |
# +---------------------------+------------+
# | good fast                 | 0.00343643 |
# +---------------------------+------------+
# | easy best                 | 0.00343643 |
# +---------------------------+------------+
# | failed transaction        | 0.00343643 |
# +---------------------------+------------+
# | pls help                  | 0.00343643 |
# +---------------------------+------------+
# | local solution            | 0.00343643 |
# +---------------------------+------------+
# | life easy                 | 0.00343643 |
# +---------------------------+------------+
# | life easier               | 0.00343643 |
# +---------------------------+------------+
# | worst extremely           | 0.00343643 |
# +---------------------------+------------+
# | lifestyle service         | 0.0034079  |
# +---------------------------+------------+
# | everything work           | 0.00328094 |
# +---------------------------+------------+
# | pay bill                  | 0.00314695 |
# +---------------------------+------------+
# | secure reliable           | 0.00308787 |
# +---------------------------+------------+
# | soon possible             | 0.00307376 |
# +---------------------------+------------+
# | best seen                 | 0.00304375 |
# +---------------------------+------------+
# | phone setting             | 0.00298363 |
# +---------------------------+------------+
# | sometimes working         | 0.00296136 |
# +---------------------------+------------+
# | amazing experience        | 0.00293317 |
# +---------------------------+------------+
# | best ui                   | 0.00293317 |
# +---------------------------+------------+
# | developer mode            | 0.00293317 |
# +---------------------------+------------+
# | change pin                | 0.00293317 |
# +---------------------------+------------+
# | finger print              | 0.00293317 |
# +---------------------------+------------+
# | easy also                 | 0.00293317 |
# +---------------------------+------------+
# | latest version            | 0.00293317 |
# +---------------------------+------------+
# | commerce feature          | 0.00278724 |
# +---------------------------+------------+
# | step forward              | 0.00263687 |
# +---------------------------+------------+
# | fast response             | 0.00262034 |
# +---------------------------+------------+
# | friendly experience       | 0.00260749 |
# +---------------------------+------------+
# | user friendly experience  | 0.00260749 |
# +---------------------------+------------+
# | overall experience        | 0.00256381 |
# +---------------------------+------------+
# | technological advancement | 0.00254997 |
# +---------------------------+------------+
# | multiple service          | 0.00253303 |
# +---------------------------+------------+
# | working say               | 0.00249892 |
# +---------------------------+------------+
# | person visit              | 0.00249892 |
# +---------------------------+------------+
# | worst used                | 0.00249892 |
# +---------------------------+------------+
# | able access               | 0.00249372 |
# +---------------------------+------------+
# | need improvement          | 0.00248662 |
# +---------------------------+------------+
# +---------------------------+------------+
# | Keyword                   |      Score |
# +===========================+============+
# | user friendly             | 0.0100033  |
# +---------------------------+------------+
# | send money                | 0.00936121 |
# +---------------------------+------------+
# | transaction history       | 0.00818653 |
# +---------------------------+------------+
# | transfer money            | 0.00632418 |
# +---------------------------+------------+
# | screen shoot              | 0.00529101 |
# +---------------------------+------------+
# | best seen                 | 0.00529101 |
# +---------------------------+------------+
# | transfer account          | 0.00529101 |
# +---------------------------+------------+
# | service charge            | 0.00529101 |
# +---------------------------+------------+
# | account number            | 0.0045916  |
# +---------------------------+------------+
# | good job                  | 0.00441814 |
# +---------------------------+------------+
# | five star                 | 0.00437817 |
# +---------------------------+------------+
# | unable connect            | 0.00407301 |
# +---------------------------+------------+
# | please fix                | 0.0040633  |
# +---------------------------+------------+
# | tele birr                 | 0.00394915 |
# +---------------------------+------------+
# | money telebirr            | 0.00371387 |
# +---------------------------+------------+
# | see transaction           | 0.00368661 |
# +---------------------------+------------+
# | nearest branch            | 0.00352734 |
# +---------------------------+------------+
# | life easier               | 0.00352734 |
# +---------------------------+------------+
# | good need                 | 0.00352734 |
# +---------------------------+------------+
# | sometimes work            | 0.00352734 |
# +---------------------------+------------+
# | service fee               | 0.00352734 |
# +---------------------------+------------+
# | show transaction          | 0.00309802 |
# +---------------------------+------------+
# | telebirr working          | 0.00306278 |
# +---------------------------+------------+
# | user turn                 | 0.00306278 |
# +---------------------------+------------+
# | interface user            | 0.00305617 |
# +---------------------------+------------+
# | interface user friendly   | 0.00305617 |
# +---------------------------+------------+
# | good saving               | 0.00301077 |
# +---------------------------+------------+
# | visit branch              | 0.00301077 |
# +---------------------------+------------+
# | atm card                  | 0.00301077 |
# +---------------------------+------------+
# | yes good                  | 0.00301077 |
# +---------------------------+------------+
# | cleared cache             | 0.00301077 |
# +---------------------------+------------+
# | telebirr wallet           | 0.0026687  |
# +---------------------------+------------+
# | say change                | 0.0026455  |
# +---------------------------+------------+
# | back work                 | 0.0024942  |
# +---------------------------+------------+
# | sim card                  | 0.00241931 |
# +---------------------------+------------+
# | name account              | 0.00221415 |
# +---------------------------+------------+
# | transfer money telebirr   | 0.00217367 |
# +---------------------------+------------+
# | see transaction history   | 0.00201582 |
# +---------------------------+------------+
# | please try                | 0.00191018 |
# +---------------------------+------------+
# | please try fix            | 0.00191018 |
# +---------------------------+------------+
# | try fix                   | 0.00191018 |
# +---------------------------+------------+
# | pin digit                 | 0.00190009 |
# +---------------------------+------------+
# | change pin digit          | 0.00190009 |
# +---------------------------+------------+
# | change pin                | 0.00190009 |
# +---------------------------+------------+
# | go back                   | 0.00175623 |
# +---------------------------+------------+
# | visit nearby              | 0.00140106 |
# +---------------------------+------------+
# | uninstalled need          | 0.00140106 |
# +---------------------------+------------+
# | holder previously         | 0.00120543 |
# +---------------------------+------------+
# | name account holder       | 0.00120543 |
# +---------------------------+------------+
# | fix asap                  | 0.00120543 |
# +---------------------------+------------+
# | please fix asap           | 0.00120543 |
# +---------------------------+------------+
# | account holder previously | 0.00120543 |
# +---------------------------+------------+
# | account holder            | 0.00120543 |
# +---------------------------+------------+
#
# === boa ===
# +-------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Theme                               | Keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +=====================================+===========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+
# | App Performance & Reliability       | developer option, best best, turn developer, working day, user friendly, user experience, sometimes work, developer mode, phone number, fix problem, disable developer, never work, transfer money, security question, previous version, send money, work well, financial company, working properly, transferring money, work device, turn developer option, disable developer option, usually crash, frequently experience, every try, worst never, work version, painfully slow, since last, know wrong, fix issue, worst experience, android phone, solve problem, money get, show error, access account, crush frequently, nice easy, android version |
# +-------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Account Access & Login              | type otp, otp code                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +-------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Customer Support & Feature Requests | good job, good service, overall good                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +-------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# === dashen ===
# +-----------------------------+-------------------------------------------------------------------------------------------------------------------------------+
# | Theme                       | Keywords                                                                                                                      |
# +=============================+===============================================================================================================================+
# | User Interface & Experience | user friendly, amazing experience, friendly experience, user friendly experience, overall experience                          |
# +-----------------------------+-------------------------------------------------------------------------------------------------------------------------------+
# | Account Access & Login      | worst extremely, worst used                                                                                                   |
# +-----------------------------+-------------------------------------------------------------------------------------------------------------------------------+
# | Transactions                | easy fast, fast reliable, fast transaction, fast secure, fast easy, good fast, easy best, life easy, easy also, fast response |
# +-----------------------------+-------------------------------------------------------------------------------------------------------------------------------+
#
# === cbe ===
# +------------------------+-----------------------------------------------------------------------------------------------------------------------------------+
# | Theme                  | Keywords                                                                                                                          |
# +========================+===================================================================================================================================+
# | Transactions           | transfer account, account number, name account, holder previously, name account holder, account holder previously, account holder |
# +------------------------+-----------------------------------------------------------------------------------------------------------------------------------+
# | Account Access & Login | say change, pin digit, change pin digit, change pin                                                                               |
# +------------------------+-----------------------------------------------------------------------------------------------------------------------------------+
