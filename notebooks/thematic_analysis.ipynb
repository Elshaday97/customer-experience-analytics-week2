# %%
# Fix imports when running from notebooks/ folder
import sys
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Added to path: /Users/elshaday/DEV/10Academy/customer-experience-analytics-week2

# %%
from src.data import DataManager
from tabulate import tabulate
from src.analysis import KeywordExtractor, ThemeClusterer
from tabulate import tabulate
import pandas as pd
from scripts.constants import THEMES
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/elshaday/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
dm = DataManager()
reviews_df = dm.load_data()

# %%
print("Showing 5 records as an overview:")
print(tabulate(reviews_df.head(), headers="keys", tablefmt="psql"))
# Out:
# Showing 5 records as an overview:
# +----+--------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+---------------+------------------+------------------+
# |    | review_id                            | review                                                                                                                                                                                                                                                                                                                                                                                                              |   rating | date                | bank   | source      | clean_review                                                                                                                                                                                                                                   |   vader_score | vader_label   |   textblob_score | textblob_label   |
# |----+--------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+---------------+------------------+------------------|
# |  0 | 0d6ae179-04ce-4b0c-900b-409198970d7a | ok                                                                                                                                                                                                                                                                                                                                                                                                                  |        1 | 2024-06-24 00:00:00 | boa    | google_play | ok                                                                                                                                                                                                                                             |        0.296  | positive      |           0.5    | positive         |
# |  1 | 2b2ff6dc-5482-4582-98ba-2ed17547e409 | Open Open service                                                                                                                                                                                                                                                                                                                                                                                                   |        5 | 2024-06-26 00:00:00 | boa    | google_play | open open service                                                                                                                                                                                                                              |        0      | neutral       |           0      | neutral          |
# |  2 | f0fe277f-65c1-461c-afad-8cd40c6ab368 | It's been two months now, I cannot do any transaction using this app. It's really disappointing. I am using bank of Abyssinia currently because it's the nearest bank to my work place. The bank is turning to the worst bank in the country day by day. They always respond to customers that they are updating their system all year long, I think that's what they train their customer service operators to do. |        1 | 2024-06-26 00:00:00 | boa    | google_play | two month cannot transaction using really disappointing using bank abyssinia currently nearest bank work place bank turning worst bank country day day always respond customer updating system year long think train customer service operator |       -0.8221 | negative      |          -0.4125 | negative         |
# |  3 | 829d9bb9-e4bc-4e04-90c2-867460eab574 | It demands to disable developer option.                                                                                                                                                                                                                                                                                                                                                                             |        1 | 2024-06-27 00:00:00 | boa    | google_play | demand disable developer option                                                                                                                                                                                                                |       -0.128  | negative      |           0      | neutral          |
# |  4 | d7273bdf-94a5-4b02-89ec-4a863195ea29 | the underrated app I've ever seen and ur banking system is Soo Idiocracy                                                                                                                                                                                                                                                                                                                                            |        1 | 2024-06-27 00:00:00 | boa    | google_play | underrated ever seen ur banking system soo idiocracy                                                                                                                                                                                           |        0      | neutral       |           0      | neutral          |
# +----+--------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+---------------+------------------+------------------+

# %%
# 1. Extract Keywords
# TfidfVectorizer with bigrams (n=1–2)
# spaCy to extract nouns/verbs if you want cleaner thematic clusters

# 2. Group keywords into themes
# 3-5 theme per bank
# Look at top TF-IDF keywords, Cluster similar keywords, Assign each cluster a theme label

# 3. Assign Theme to Each Review
# Check if any keyword from a theme appears
# Add a theme column

# 4. Group by bank and theme
# Count of each theme per bank
# Average sentiment per theme
# Top keywords per theme
# Correlation between rating and sentiment

# %%
extractor = KeywordExtractor()
clusterer = ThemeClusterer(n_clusters=5)


def analyze( df: pd.DataFrame, review_col: str, bank_col: str):
    bank_themes = {}
    for bank in df[bank_col].unique():
        bank_reviews = df.loc[df[bank_col] == bank, review_col].astype(str)
        # Extract keywords
        kw_with_scores = extractor.extract_keywords_tfidf(bank_reviews)
        keywords = [kw for kw, _ in kw_with_scores]
        # Cluster keywords into themes
        clusters = clusterer.cluster(keywords)
        themes = clusterer.assign_labels(clusters)
        bank_themes[bank] = themes

    return bank_themes


# Run per-bank theme analysis
bank_themes = analyze(
    reviews_df, review_col="clean_review", bank_col="bank"
)

# Display
for bank, themes in bank_themes.items():
    print(f"\n=== {bank} ===")
    rows = [[theme, ", ".join(words)] for theme, words in themes.items()]
    print(tabulate(rows, headers=["Theme", "Keywords"], tablefmt="grid"))
# Out:
# === boa ===
# +-------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Theme                               | Keywords                                                                                                                                                           |
# +=====================================+====================================================================================================================================================================+
# | App Performance & Reliability       | please fix, please try, sometimes work, never work, working please, work well, work device, please check, work version, please working, work please, please invest |
# +-------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Customer Support & Feature Requests | good job, good service, great service, customer service, overall good, service please                                                                              |
# +-------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Transactions                        | transaction please                                                                                                                                                 |
# +-------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Account Access & Login              | type otp, otp code                                                                                                                                                 |
# +-------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# === dashen ===
# +-------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Theme                         | Keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +===============================+=======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+
# | User Interface & Experience   | game changer, easy fast, user interface, best best, developer option, qr code, everything need, highly recommended, ui ux, good job, fast reliable, good work, fast transaction, fast secure, fast easy, please try, life easy, thing need, local solution, pls help, good fast, life easier, soon possible, easy best, best seen, failed transaction, lifestyle service, everything work, secure reliable, phone setting, change pin, easy also, latest version, finger print, best ui, developer mode, commerce feature, able access, fast response, person visit, technological advancement, multiple service, need improvement, security feature, transfer money, send money, innovation delivers |
# +-------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Transactions                  | bill payment, pay bill                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +-------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | App Performance & Reliability | worst extremely, worst used                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +-------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# === cbe ===
# +-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Theme                         | Keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +===============================+===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+
# | User Interface & Experience   | user friendly, user turn, interface user, interface user friendly                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | App Performance & Reliability | send money, transfer money, screen shoot, best seen, service charge, good job, five star, unable connect, please fix, tele birr, money telebirr, nearest branch, life easier, good need, service fee, telebirr working, good saving, visit branch, atm card, yes good, cleared cache, telebirr wallet, say change, sim card, transfer money telebirr, please try, please try fix, try fix, pin digit, change pin digit, change pin, visit nearby, uninstalled need, fix asap, please fix asap |
# +-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Transactions                  | transfer account, account number, name account, holder previously, name account holder, account holder previously, account holder                                                                                                                                                                                                                                                                                                                                                             |
# +-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Other 0                       | sometimes work, back work                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
print("Apply theme per review")
def assign_theme_to_review(review_text: str, theme_dict: dict) -> str:
    """
    Assign a theme to a single review based on keyword matches.
    Returns 'Other' if no theme matches.
    """
    if not isinstance(review_text, str):
        return "Other"

    text = review_text.lower()

    for theme, keywords in theme_dict.items():
        for kw in keywords:
            if kw.lower() in text:
                return theme

    return "Other"


reviews_df["theme"] = reviews_df["clean_review"].apply(lambda txt: assign_theme_to_review(txt, THEMES))

print(tabulate(reviews_df[["theme", "clean_review"]].head(), headers=["Clean Review", "Theme"], tablefmt="grid"))
# Out:
# +----+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    | Clean Review                        | Theme                                                                                                                                                                                                                                          |
# +====+=====================================+================================================================================================================================================================================================================================================+
# |  0 | Other                               | ok                                                                                                                                                                                                                                             |
# +----+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  1 | Customer Support & Feature Requests | open open service                                                                                                                                                                                                                              |
# +----+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  2 | Transactions                        | two month cannot transaction using really disappointing using bank abyssinia currently nearest bank work place bank turning worst bank country day day always respond customer updating system year long think train customer service operator |
# +----+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  3 | Account Access & Login              | demand disable developer option                                                                                                                                                                                                                |
# +----+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  4 | Other                               | underrated ever seen ur banking system soo idiocracy                                                                                                                                                                                           |
# +----+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
print("Save to csv")

dm.save_to_csv(df=reviews_df, processed=True)
# Out:
# Save to csv
# Saved data to ../data/processed/cleaned_reviews_data.csv
