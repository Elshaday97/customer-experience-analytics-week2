# %%
# Fix imports when running from notebooks/ folder
import sys
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Added to path: /Users/elshaday/DEV/10Academy/customer-experience-analytics-week2
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data import DataManager
from tabulate import tabulate

# %%
# Scrape Data and save to csv
dm = DataManager()
dm.scrape_reviews()
reviews_df = dm.load_data()
# Out:
# Removed 0 rows with missing values.
# Removed 79 rows with Ethiopic reviews.
# Saved cleaned data to ../data/reviews_data.csv

# %%
print(tabulate(reviews_df.head(), headers="keys", tablefmt="psql"))
# Out:
# +----+--------------------------------------+--------------------------------------------------------------+----------+---------------------+--------+
# |    | review_id                            | review                                                       |   rating | date                | bank   |
# |----+--------------------------------------+--------------------------------------------------------------+----------+---------------------+--------|
# |  0 | c051070a-5552-441b-9c04-ff28664018fe | Always error occured. The worst app ever                     |        1 | 2024-06-20 00:00:00 | boa    |
# |  1 | efe89d62-85f0-453d-bc34-e71402cb2f09 | Riddled with crashes, cant use it anymore. Very frustrating! |        1 | 2024-06-20 00:00:00 | boa    |
# |  2 | 0d6ae179-04ce-4b0c-900b-409198970d7a | ok                                                           |        1 | 2024-06-24 00:00:00 | boa    |
# |  3 | a390a52e-ca04-40d3-9b31-36f99d60aa99 | Its not working.                                             |        1 | 2024-06-24 00:00:00 | boa    |
# |  4 | 2b2ff6dc-5482-4582-98ba-2ed17547e409 | Open Open service                                            |        5 | 2024-06-26 00:00:00 | boa    |
# +----+--------------------------------------+--------------------------------------------------------------+----------+---------------------+--------+
# bank
# boa       572
# cbe       567
# dashen    582
# dtype: int64
