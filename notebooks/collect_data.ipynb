# %%
# Fix imports when running from notebooks/ folder
import sys
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Added to path: /Users/elshaday/DEV/10Academy/customer-experience-analytics-week2
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data import DataManager
from tabulate import tabulate

# %%
# Scrape Data and save to csv
dm = DataManager()
dm.scrape_reviews()
# Out:
# Successfully saved to file reviews_data.csv

# %%
# Understanding Structure
reviews_df = dm.load_data()
print(tabulate(reviews_df.head(), headers="keys", tablefmt="psql"))
# Out:
# +----+--------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+
# |    | review_id                            | review                                                                                                                                                                                                                                                                                                                                                |   rating | date                | bank   |
# |----+--------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------|
# |  0 | d29af33e-3f63-4b7e-9312-b63f7d2c6724 | What do you care about my phone's settings? Who are you to tell me what to turn off and on? It is my phone after all. This *develoler option* thing will cost you a lot of users who are willing to leave the bank once and for all. Turn this thing off. 6 you fear this is a security issue fix your side not mine.                                 |        1 | 2025-11-25 17:03:10 | dashen |
# |  1 | 9b84c588-bde5-46b7-930c-c638ca26212d | Exceptional Product.                                                                                                                                                                                                                                                                                                                                  |        5 | 2025-11-23 11:49:24 | dashen |
# |  2 | 3d668840-c868-4164-8efe-9295ef537613 | very easy app                                                                                                                                                                                                                                                                                                                                         |        3 | 2025-11-23 08:37:38 | dashen |
# |  3 | eeb816b9-14d4-4d91-a3b5-90b391850faa | The Dashen Super App is very impressive. It is fast, easy to use, and provides smooth access to all essential banking services. Money transfer, bill payment, balance check, and other features work efficiently without issues. The design is clean and user-friendly. Great step forward in digital banking — keep up the good work, Dashen Bank!.. |        5 | 2025-11-19 20:51:58 | dashen |
# |  4 | bfff7fbc-253a-4538-9483-345a271fc2eb | በጣም ፈጣን ሥቹ አስተማማኝ ወድጃዋለው                                                                                                                                                                                                                                                                                                                              |        5 | 2025-11-18 22:05:15 | dashen |
# +----+--------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+---------------------+--------+
